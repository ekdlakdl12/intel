# %% [markdown]
# <a href="https://colab.research.google.com/github/ekdlakdl12/intel/blob/main/KakaoChatTerror.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyautogui
import time

#pyautogui.screenshot('white.png',region =(1200, 800, 50,30)) #1200,800위치에 50*30크기로 캡쳐 /캡쳐필요할시 코드 활성화

a1= pyautogui.locateCenterOnScreen('white.PNG') #파일 넣어두기
pyautogui.moveTo(a1) #화면 캡쳐한 곳 가운데로 이동

pyautogui.click() #한번 클릭
time.sleep(1) #1초 대기

for i in range(500) :
    pyautogui.write('Hello World!')
    pyautogui.write(['enter'])

# %% [markdown]
# # 이미지파일 참조
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# #pyinstaller 통해 실행기 생성
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# # 생성완료
# ![img1.daumcdn.png](data:image/png;base64,...)
