# %%
# 비트코인 가격 데이터 읽기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 코인데스크 사이트에서 다운로드한 1년치 비트코인 가격 데이터 읽기
f=open('/content/BTC_USD_2019-02-28_2020-02-27-CoinDesk.csv','r')
coindesk_data=pd.read_csv(f,header=0)
seq=coindesk_data[['Closing Price (USD)']].to_numpy() # 종가만 취함
print('데이터 길이:',len(seq),'\n앞쪽 5개 값:',seq[0:5])

# 그래프로 데이터 확인
plt.plot(seq,color='red')
plt.title('Bitcoin Prices (1 year from 2019-02-28)')
plt.xlabel('Days');plt.ylabel('Price in USD')
plt.show()
# Out:
# 데이터 길이: 365
# 앞쪽 5개 값: [[3772.93633533]
#  [3799.67854295]
#  [3811.61197937]
#  [3804.41917011]
#  [3782.66410112]]
# (358, 7, 1) (358, 1)
# [[3772.93633533]
#  [3799.67854295]
#  [3811.61197937]
#  [3804.41917011]
#  [3782.66410112]
#  [3689.86289319]
#  [3832.08088473]] [3848.95636968]
# [[9631.48494596]
#  [9670.85865437]
#  [9689.08674285]
#  [9919.55144784]
#  [9640.46950506]
#  [9392.86962872]
#  [8787.97836316]] [8784.99535244]

# %%
# 1년치 비트코인 가격 데이터를 윈도우로 자르기

# 시계열 데이터를 윈도우 단위로 자르는 함수
def seq2dataset(seq,window,horizon):
    X=[]; Y=[]
    for i in range(len(seq)-(window+horizon)+1):
        x=seq[i:(i+window)]
        y=(seq[i+window+horizon-1])
        X.append(x); Y.append(y)
    return np.array(X), np.array(Y)

w=7 # 윈도우 크기
h=1 # 수평선 계수

X,Y = seq2dataset(seq,w,h)
print(X.shape,Y.shape)
print(X[0],Y[0]); print(X[-1],Y[-1])

# %%
# LSTM을 이용한 비트코인 가격 예측


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 코인데스크 사이트에서 1년치 비트코인 가격 데이터 읽기
f=open("/content/BTC_USD_2019-02-28_2020-02-27-CoinDesk.csv","r")
coindesk_data=pd.read_csv(f,header=0)
seq=coindesk_data[['Closing Price (USD)']].to_numpy() # 종가만 취함

# 시계열 데이터를 윈도우 단위로 자르는 함수
def seq2dataset(seq,window,horizon):
    X=[]; Y=[]
    for i in range(len(seq)-(window+horizon)+1):
        x=seq[i:(i+window)]
        y=(seq[i+window+horizon-1])
        X.append(x); Y.append(y)
    return np.array(X), np.array(Y)

w=7 # 윈도우 크기
h=1 # 수평선 계수

X,Y=seq2dataset(seq,w,h)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# 훈련 집합과 테스트 집합으로 분할
split=int(len(X)*0.7)
x_train=X[0:split]; y_train=Y[0:split]
x_test=X[split:]; y_test=Y[split:]

# LSTM 모델 설계와 학습
model=Sequential()
model.add(LSTM(units=128,activation='relu',input_shape=x_train[0].shape))
model.add(Dense(1))
model.compile(loss='mae',optimizer='adam',metrics=['mae'])
hist=model.fit(x_train,y_train,epochs=200,batch_size=1,validation_data=(x_test,y_test),verbose=2)

# LSTM 모델 평가
ev=model.evaluate(x_test,y_test,verbose=0)
print("손실 함수:",ev[0],"MAE:",ev[1])

# LSTM 모델로 예측 수행
pred=model.predict(x_test)
print("평균절댓값백분율오차(MAPE):",sum(abs(y_test-pred)/y_test)/len(x_test))

# 학습 곡선
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('Model mae')
plt.ylabel('mae')
plt.xlabel('Epoch')
plt.ylim([120,800])
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()

# 예측 결과 시각화
x_range=range(len(y_test))
plt.plot(x_range,y_test[x_range], color='red')
plt.plot(x_range,pred[x_range], color='blue')
plt.legend(['True prices','Predicted prices'], loc='best')
plt.grid()
plt.show()

# 일부 구간을 확대하여 시각화
x_range=range(50,64)
plt.plot(x_range,y_test[x_range], color='red')
plt.plot(x_range,pred[x_range], color='blue')
plt.legend(['True prices','Predicted prices'], loc='best')
plt.grid()
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/200
# 250/250 - 5s - loss: 1407.3086 - mae: 1407.3086 - val_loss: 365.4534 - val_mae: 365.4534 - 5s/epoch - 19ms/step
# Epoch 2/200
# 250/250 - 1s - loss: 580.6379 - mae: 580.6379 - val_loss: 379.4648 - val_mae: 379.4648 - 1s/epoch - 5ms/step
# Epoch 3/200
# 250/250 - 1s - loss: 557.0147 - mae: 557.0147 - val_loss: 457.3035 - val_mae: 457.3035 - 1s/epoch - 5ms/step
# Epoch 4/200
# 250/250 - 1s - loss: 503.9242 - mae: 503.9242 - val_loss: 331.7897 - val_mae: 331.7897 - 1s/epoch - 5ms/step
# Epoch 5/200
# 250/250 - 1s - loss: 519.1332 - mae: 519.1332 - val_loss: 366.9433 - val_mae: 366.9433 - 1s/epoch - 5ms/step
# Epoch 6/200
# 250/250 - 1s - loss: 524.0782 - mae: 524.0782 - val_loss: 373.5779 - val_mae: 373.5779 - 1s/epoch - 5ms/step
# Epoch 7/200
# 250/250 - 1s - loss: 536.4233 - mae: 536.4233 - val_loss: 545.0676 - val_mae: 545.0676 - 1s/epoch - 5ms/step
# Epoch 8/200
# 250/250 - 1s - loss: 557.0204 - mae: 557.0204 - val_loss: 526.2576 - val_mae: 526.2576 - 1s/epoch - 5ms/step
# Epoch 9/200
# 250/250 - 1s - loss: 596.8698 - mae: 596.8698 - val_loss: 369.1217 - val_mae: 369.1217 - 1s/epoch - 5ms/step
# Epoch 10/200
# 250/250 - 1s - loss: 546.9868 - mae: 546.9868 - val_loss: 324.3204 - val_mae: 324.3204 - 1s/epoch - 5ms/step
# Epoch 11/200
# 250/250 - 1s - loss: 506.0493 - mae: 506.0493 - val_loss: 329.6955 - val_mae: 329.6955 - 1s/epoch - 5ms/step
# Epoch 12/200
# 250/250 - 1s - loss: 536.2394 - mae: 536.2394 - val_loss: 397.3307 - val_mae: 397.3307 - 1s/epoch - 5ms/step
# Epoch 13/200
# 250/250 - 1s - loss: 524.2841 - mae: 524.2841 - val_loss: 327.6785 - val_mae: 327.6785 - 1s/epoch - 5ms/step
# Epoch 14/200
# 250/250 - 1s - loss: 488.1467 - mae: 488.1467 - val_loss: 336.0771 - val_mae: 336.0771 - 1s/epoch - 5ms/step
# Epoch 15/200
# 250/250 - 1s - loss: 488.1681 - mae: 488.1681 - val_loss: 418.2419 - val_mae: 418.2419 - 1s/epoch - 5ms/step
# Epoch 16/200
# 250/250 - 1s - loss: 485.1394 - mae: 485.1394 - val_loss: 375.3856 - val_mae: 375.3856 - 1s/epoch - 5ms/step
# Epoch 17/200
# 250/250 - 1s - loss: 496.6914 - mae: 496.6914 - val_loss: 303.4196 - val_mae: 303.4196 - 1s/epoch - 5ms/step
# Epoch 18/200
# 250/250 - 1s - loss: 519.0112 - mae: 519.0112 - val_loss: 340.8034 - val_mae: 340.8034 - 1s/epoch - 5ms/step
# Epoch 19/200
# 250/250 - 1s - loss: 514.9454 - mae: 514.9454 - val_loss: 522.8876 - val_mae: 522.8876 - 1s/epoch - 5ms/step
# Epoch 20/200
# 250/250 - 1s - loss: 495.2610 - mae: 495.2610 - val_loss: 456.8486 - val_mae: 456.8486 - 1s/epoch - 5ms/step
# Epoch 21/200
# 250/250 - 1s - loss: 475.7877 - mae: 475.7877 - val_loss: 316.4190 - val_mae: 316.4190 - 1s/epoch - 6ms/step
# Epoch 22/200
# 250/250 - 1s - loss: 511.7422 - mae: 511.7422 - val_loss: 387.5315 - val_mae: 387.5315 - 1s/epoch - 5ms/step
# Epoch 23/200
# 250/250 - 1s - loss: 558.6121 - mae: 558.6121 - val_loss: 297.8484 - val_mae: 297.8484 - 1s/epoch - 6ms/step
# Epoch 24/200
# 250/250 - 1s - loss: 475.2616 - mae: 475.2616 - val_loss: 424.3862 - val_mae: 424.3862 - 1s/epoch - 6ms/step
# Epoch 25/200
# 250/250 - 1s - loss: 523.5717 - mae: 523.5717 - val_loss: 309.1188 - val_mae: 309.1188 - 1s/epoch - 5ms/step
# Epoch 26/200
# 250/250 - 1s - loss: 483.1411 - mae: 483.1411 - val_loss: 293.3177 - val_mae: 293.3177 - 1s/epoch - 5ms/step
# Epoch 27/200
# 250/250 - 1s - loss: 450.7581 - mae: 450.7581 - val_loss: 288.3218 - val_mae: 288.3218 - 1s/epoch - 6ms/step
# Epoch 28/200
# 250/250 - 1s - loss: 448.3119 - mae: 448.3119 - val_loss: 280.5318 - val_mae: 280.5318 - 1s/epoch - 5ms/step
# Epoch 29/200
# 250/250 - 1s - loss: 433.9450 - mae: 433.9450 - val_loss: 291.7718 - val_mae: 291.7718 - 1s/epoch - 5ms/step
# Epoch 30/200
# 250/250 - 1s - loss: 434.3347 - mae: 434.3347 - val_loss: 272.9044 - val_mae: 272.9044 - 1s/epoch - 5ms/step
# Epoch 31/200
# 250/250 - 1s - loss: 427.6579 - mae: 427.6579 - val_loss: 274.4282 - val_mae: 274.4282 - 1s/epoch - 5ms/step
# Epoch 32/200
# 250/250 - 1s - loss: 422.5912 - mae: 422.5912 - val_loss: 329.1801 - val_mae: 329.1801 - 1s/epoch - 5ms/step
# Epoch 33/200
# 250/250 - 1s - loss: 411.4327 - mae: 411.4327 - val_loss: 262.2680 - val_mae: 262.2680 - 1s/epoch - 5ms/step
# Epoch 34/200
# 250/250 - 1s - loss: 437.9682 - mae: 437.9682 - val_loss: 454.7516 - val_mae: 454.7516 - 1s/epoch - 5ms/step
# Epoch 35/200
# 250/250 - 1s - loss: 410.2278 - mae: 410.2278 - val_loss: 252.2871 - val_mae: 252.2871 - 1s/epoch - 5ms/step
# Epoch 36/200
# 250/250 - 1s - loss: 404.5346 - mae: 404.5346 - val_loss: 241.4664 - val_mae: 241.4664 - 1s/epoch - 5ms/step
# Epoch 37/200
# 250/250 - 1s - loss: 410.7478 - mae: 410.7478 - val_loss: 237.9896 - val_mae: 237.9896 - 1s/epoch - 6ms/step
# Epoch 38/200
# 250/250 - 1s - loss: 372.4098 - mae: 372.4098 - val_loss: 419.8262 - val_mae: 419.8262 - 1s/epoch - 5ms/step
# Epoch 39/200
# 250/250 - 1s - loss: 415.2594 - mae: 415.2594 - val_loss: 243.5009 - val_mae: 243.5009 - 1s/epoch - 5ms/step
# Epoch 40/200
# 250/250 - 1s - loss: 343.8933 - mae: 343.8933 - val_loss: 225.3277 - val_mae: 225.3277 - 1s/epoch - 5ms/step
# Epoch 41/200
# 250/250 - 1s - loss: 359.8868 - mae: 359.8868 - val_loss: 397.8805 - val_mae: 397.8805 - 1s/epoch - 5ms/step
# Epoch 42/200
# 250/250 - 2s - loss: 365.5573 - mae: 365.5573 - val_loss: 295.1452 - val_mae: 295.1452 - 2s/epoch - 6ms/step
# Epoch 43/200
# 250/250 - 2s - loss: 359.6544 - mae: 359.6544 - val_loss: 215.1961 - val_mae: 215.1961 - 2s/epoch - 7ms/step
# Epoch 44/200
# 250/250 - 2s - loss: 323.4472 - mae: 323.4472 - val_loss: 210.2164 - val_mae: 210.2164 - 2s/epoch - 10ms/step
# Epoch 45/200
# 250/250 - 2s - loss: 329.1823 - mae: 329.1823 - val_loss: 253.5636 - val_mae: 253.5636 - 2s/epoch - 7ms/step
# Epoch 46/200
# 250/250 - 1s - loss: 331.6327 - mae: 331.6327 - val_loss: 359.4658 - val_mae: 359.4658 - 1s/epoch - 5ms/step
# Epoch 47/200
# 250/250 - 1s - loss: 293.1074 - mae: 293.1074 - val_loss: 578.2050 - val_mae: 578.2050 - 1s/epoch - 5ms/step
# Epoch 48/200
# 250/250 - 2s - loss: 326.4842 - mae: 326.4842 - val_loss: 278.7203 - val_mae: 278.7203 - 2s/epoch - 6ms/step
# Epoch 49/200
# 250/250 - 1s - loss: 303.9002 - mae: 303.9002 - val_loss: 283.8512 - val_mae: 283.8512 - 1s/epoch - 5ms/step
# Epoch 50/200
# 250/250 - 1s - loss: 317.2701 - mae: 317.2701 - val_loss: 233.1542 - val_mae: 233.1542 - 1s/epoch - 5ms/step
# Epoch 51/200
# 250/250 - 1s - loss: 297.3877 - mae: 297.3877 - val_loss: 237.5735 - val_mae: 237.5735 - 1s/epoch - 5ms/step
# Epoch 52/200
# 250/250 - 1s - loss: 314.5486 - mae: 314.5486 - val_loss: 208.4150 - val_mae: 208.4150 - 1s/epoch - 5ms/step
# Epoch 53/200
# 250/250 - 1s - loss: 306.4881 - mae: 306.4881 - val_loss: 188.0765 - val_mae: 188.0765 - 1s/epoch - 6ms/step
# Epoch 54/200
# 250/250 - 1s - loss: 311.7671 - mae: 311.7671 - val_loss: 230.0542 - val_mae: 230.0542 - 1s/epoch - 5ms/step
# Epoch 55/200
# 250/250 - 1s - loss: 281.9604 - mae: 281.9604 - val_loss: 267.0912 - val_mae: 267.0912 - 1s/epoch - 5ms/step
# Epoch 56/200
# 250/250 - 1s - loss: 289.1340 - mae: 289.1340 - val_loss: 268.3212 - val_mae: 268.3212 - 1s/epoch - 5ms/step
# Epoch 57/200
# 250/250 - 1s - loss: 284.5857 - mae: 284.5857 - val_loss: 178.8644 - val_mae: 178.8644 - 1s/epoch - 5ms/step
# Epoch 58/200
# 250/250 - 1s - loss: 286.8092 - mae: 286.8092 - val_loss: 188.1192 - val_mae: 188.1192 - 1s/epoch - 5ms/step
# Epoch 59/200
# 250/250 - 1s - loss: 273.4098 - mae: 273.4098 - val_loss: 178.1034 - val_mae: 178.1034 - 1s/epoch - 5ms/step
# Epoch 60/200
# 250/250 - 1s - loss: 280.3849 - mae: 280.3849 - val_loss: 246.0809 - val_mae: 246.0809 - 1s/epoch - 5ms/step
# Epoch 61/200
# 250/250 - 1s - loss: 277.3362 - mae: 277.3362 - val_loss: 258.8414 - val_mae: 258.8414 - 1s/epoch - 5ms/step
# Epoch 62/200
# 250/250 - 1s - loss: 288.2756 - mae: 288.2756 - val_loss: 235.0036 - val_mae: 235.0036 - 1s/epoch - 5ms/step
# Epoch 63/200
# 250/250 - 2s - loss: 306.5923 - mae: 306.5923 - val_loss: 232.2639 - val_mae: 232.2639 - 2s/epoch - 9ms/step
# Epoch 64/200
# 250/250 - 2s - loss: 272.4472 - mae: 272.4472 - val_loss: 176.2626 - val_mae: 176.2626 - 2s/epoch - 9ms/step
# Epoch 65/200
# 250/250 - 3s - loss: 276.0002 - mae: 276.0002 - val_loss: 246.5675 - val_mae: 246.5675 - 3s/epoch - 10ms/step
# Epoch 66/200
# 250/250 - 2s - loss: 258.2236 - mae: 258.2236 - val_loss: 226.8591 - val_mae: 226.8591 - 2s/epoch - 8ms/step
# Epoch 67/200
# 250/250 - 2s - loss: 267.0097 - mae: 267.0097 - val_loss: 267.8697 - val_mae: 267.8697 - 2s/epoch - 8ms/step
# Epoch 68/200
# 250/250 - 2s - loss: 268.8623 - mae: 268.8623 - val_loss: 179.6413 - val_mae: 179.6413 - 2s/epoch - 7ms/step
# Epoch 69/200
# 250/250 - 2s - loss: 289.8540 - mae: 289.8540 - val_loss: 267.1137 - val_mae: 267.1137 - 2s/epoch - 7ms/step
# Epoch 70/200
# 250/250 - 2s - loss: 269.1277 - mae: 269.1277 - val_loss: 193.0463 - val_mae: 193.0463 - 2s/epoch - 9ms/step
# Epoch 71/200
# 250/250 - 1s - loss: 273.9908 - mae: 273.9908 - val_loss: 172.7492 - val_mae: 172.7492 - 1s/epoch - 5ms/step
# Epoch 72/200
# 250/250 - 1s - loss: 266.8319 - mae: 266.8319 - val_loss: 171.9433 - val_mae: 171.9433 - 1s/epoch - 5ms/step
# Epoch 73/200
# 250/250 - 1s - loss: 287.6208 - mae: 287.6208 - val_loss: 181.4040 - val_mae: 181.4040 - 1s/epoch - 5ms/step
# Epoch 74/200
# 250/250 - 1s - loss: 262.1407 - mae: 262.1407 - val_loss: 169.6378 - val_mae: 169.6378 - 1s/epoch - 5ms/step
# Epoch 75/200
# 250/250 - 1s - loss: 257.1542 - mae: 257.1542 - val_loss: 223.9558 - val_mae: 223.9558 - 1s/epoch - 5ms/step
# Epoch 76/200
# 250/250 - 1s - loss: 262.1524 - mae: 262.1524 - val_loss: 184.0692 - val_mae: 184.0692 - 1s/epoch - 5ms/step
# Epoch 77/200
# 250/250 - 1s - loss: 263.0413 - mae: 263.0413 - val_loss: 257.0091 - val_mae: 257.0091 - 1s/epoch - 5ms/step
# Epoch 78/200
# 250/250 - 1s - loss: 272.0354 - mae: 272.0354 - val_loss: 223.7310 - val_mae: 223.7310 - 1s/epoch - 5ms/step
# Epoch 79/200
# 250/250 - 1s - loss: 255.2379 - mae: 255.2379 - val_loss: 179.3763 - val_mae: 179.3763 - 1s/epoch - 6ms/step
# Epoch 80/200
# 250/250 - 1s - loss: 269.9339 - mae: 269.9339 - val_loss: 205.8158 - val_mae: 205.8158 - 1s/epoch - 5ms/step
# Epoch 81/200
# 250/250 - 1s - loss: 274.1451 - mae: 274.1451 - val_loss: 219.2345 - val_mae: 219.2345 - 1s/epoch - 6ms/step
# Epoch 82/200
# 250/250 - 1s - loss: 278.2918 - mae: 278.2918 - val_loss: 176.1034 - val_mae: 176.1034 - 1s/epoch - 5ms/step
# Epoch 83/200
# 250/250 - 1s - loss: 264.7538 - mae: 264.7538 - val_loss: 189.7010 - val_mae: 189.7010 - 1s/epoch - 6ms/step
# Epoch 84/200
# 250/250 - 1s - loss: 264.3514 - mae: 264.3514 - val_loss: 173.7092 - val_mae: 173.7092 - 1s/epoch - 5ms/step
# Epoch 85/200
# 250/250 - 1s - loss: 271.6946 - mae: 271.6946 - val_loss: 192.2692 - val_mae: 192.2692 - 1s/epoch - 6ms/step
# Epoch 86/200
# 250/250 - 1s - loss: 253.9308 - mae: 253.9308 - val_loss: 170.5533 - val_mae: 170.5533 - 1s/epoch - 5ms/step
# Epoch 87/200
# 250/250 - 1s - loss: 280.3527 - mae: 280.3527 - val_loss: 250.8516 - val_mae: 250.8516 - 1s/epoch - 5ms/step
# Epoch 88/200
# 250/250 - 1s - loss: 278.7170 - mae: 278.7170 - val_loss: 266.1667 - val_mae: 266.1667 - 1s/epoch - 5ms/step
# Epoch 89/200
# 250/250 - 1s - loss: 270.3580 - mae: 270.3580 - val_loss: 308.8289 - val_mae: 308.8289 - 1s/epoch - 5ms/step
# Epoch 90/200
# 250/250 - 1s - loss: 266.0745 - mae: 266.0745 - val_loss: 170.9905 - val_mae: 170.9905 - 1s/epoch - 5ms/step
# Epoch 91/200
# 250/250 - 1s - loss: 260.5266 - mae: 260.5266 - val_loss: 195.4781 - val_mae: 195.4781 - 1s/epoch - 5ms/step
# Epoch 92/200
# 250/250 - 1s - loss: 282.4283 - mae: 282.4283 - val_loss: 174.6470 - val_mae: 174.6470 - 1s/epoch - 5ms/step
# Epoch 93/200
# 250/250 - 1s - loss: 257.5073 - mae: 257.5073 - val_loss: 168.2244 - val_mae: 168.2244 - 1s/epoch - 5ms/step
# Epoch 94/200
# 250/250 - 1s - loss: 266.2378 - mae: 266.2378 - val_loss: 193.3637 - val_mae: 193.3637 - 1s/epoch - 5ms/step
# Epoch 95/200
# 250/250 - 1s - loss: 265.9311 - mae: 265.9311 - val_loss: 182.3772 - val_mae: 182.3772 - 1s/epoch - 5ms/step
# Epoch 96/200
# 250/250 - 1s - loss: 259.2455 - mae: 259.2455 - val_loss: 171.8859 - val_mae: 171.8859 - 1s/epoch - 5ms/step
# Epoch 97/200
# 250/250 - 1s - loss: 253.9339 - mae: 253.9339 - val_loss: 177.6255 - val_mae: 177.6255 - 1s/epoch - 5ms/step
# Epoch 98/200
# 250/250 - 1s - loss: 274.3950 - mae: 274.3950 - val_loss: 197.0312 - val_mae: 197.0312 - 1s/epoch - 5ms/step
# Epoch 99/200
# 250/250 - 1s - loss: 254.6836 - mae: 254.6836 - val_loss: 167.6974 - val_mae: 167.6974 - 1s/epoch - 6ms/step
# Epoch 100/200
# 250/250 - 1s - loss: 248.7710 - mae: 248.7710 - val_loss: 186.9525 - val_mae: 186.9525 - 1s/epoch - 5ms/step
# Epoch 101/200
# 250/250 - 1s - loss: 261.0161 - mae: 261.0161 - val_loss: 176.5224 - val_mae: 176.5224 - 1s/epoch - 5ms/step
# Epoch 102/200
# 250/250 - 2s - loss: 256.8671 - mae: 256.8671 - val_loss: 185.3143 - val_mae: 185.3143 - 2s/epoch - 7ms/step
# Epoch 103/200
# 250/250 - 2s - loss: 262.5564 - mae: 262.5564 - val_loss: 167.0983 - val_mae: 167.0983 - 2s/epoch - 9ms/step
# Epoch 104/200
# 250/250 - 1s - loss: 252.6660 - mae: 252.6660 - val_loss: 167.0051 - val_mae: 167.0051 - 1s/epoch - 6ms/step
# Epoch 105/200
# 250/250 - 1s - loss: 254.5536 - mae: 254.5536 - val_loss: 178.0116 - val_mae: 178.0116 - 1s/epoch - 5ms/step
# Epoch 106/200
# 250/250 - 1s - loss: 249.7253 - mae: 249.7253 - val_loss: 168.4400 - val_mae: 168.4400 - 1s/epoch - 5ms/step
# Epoch 107/200
# 250/250 - 1s - loss: 265.0499 - mae: 265.0499 - val_loss: 219.2689 - val_mae: 219.2689 - 1s/epoch - 5ms/step
# Epoch 108/200
# 250/250 - 1s - loss: 258.8640 - mae: 258.8640 - val_loss: 248.4746 - val_mae: 248.4746 - 1s/epoch - 5ms/step
# Epoch 109/200
# 250/250 - 1s - loss: 252.1974 - mae: 252.1974 - val_loss: 166.8133 - val_mae: 166.8133 - 1s/epoch - 6ms/step
# Epoch 110/200
# 250/250 - 1s - loss: 267.2518 - mae: 267.2518 - val_loss: 248.6050 - val_mae: 248.6050 - 1s/epoch - 5ms/step
# Epoch 111/200
# 250/250 - 1s - loss: 246.2182 - mae: 246.2182 - val_loss: 236.7314 - val_mae: 236.7314 - 1s/epoch - 5ms/step
# Epoch 112/200
# 250/250 - 1s - loss: 262.4525 - mae: 262.4525 - val_loss: 171.3454 - val_mae: 171.3454 - 1s/epoch - 5ms/step
# Epoch 113/200
# 250/250 - 1s - loss: 262.3641 - mae: 262.3641 - val_loss: 208.3187 - val_mae: 208.3187 - 1s/epoch - 5ms/step
# Epoch 114/200
# 250/250 - 1s - loss: 254.8228 - mae: 254.8228 - val_loss: 175.6583 - val_mae: 175.6583 - 1s/epoch - 5ms/step
# Epoch 115/200
# 250/250 - 1s - loss: 246.8620 - mae: 246.8620 - val_loss: 173.5754 - val_mae: 173.5754 - 1s/epoch - 5ms/step
# Epoch 116/200
# 250/250 - 1s - loss: 248.8813 - mae: 248.8813 - val_loss: 166.5229 - val_mae: 166.5229 - 1s/epoch - 5ms/step
# Epoch 117/200
# 250/250 - 1s - loss: 249.7017 - mae: 249.7017 - val_loss: 167.2990 - val_mae: 167.2990 - 1s/epoch - 5ms/step
# Epoch 118/200
# 250/250 - 1s - loss: 269.8973 - mae: 269.8973 - val_loss: 166.4307 - val_mae: 166.4307 - 1s/epoch - 5ms/step
# Epoch 119/200
# 250/250 - 1s - loss: 252.3255 - mae: 252.3255 - val_loss: 168.0285 - val_mae: 168.0285 - 1s/epoch - 5ms/step
# Epoch 120/200
# 250/250 - 1s - loss: 268.0038 - mae: 268.0038 - val_loss: 167.1534 - val_mae: 167.1534 - 1s/epoch - 5ms/step
# Epoch 121/200
# 250/250 - 1s - loss: 261.8009 - mae: 261.8009 - val_loss: 169.8946 - val_mae: 169.8946 - 1s/epoch - 5ms/step
# Epoch 122/200
# 250/250 - 1s - loss: 259.1187 - mae: 259.1187 - val_loss: 188.7379 - val_mae: 188.7379 - 1s/epoch - 5ms/step
# Epoch 123/200
# 250/250 - 1s - loss: 260.5954 - mae: 260.5954 - val_loss: 184.7736 - val_mae: 184.7736 - 1s/epoch - 5ms/step
# Epoch 124/200
# 250/250 - 1s - loss: 251.0740 - mae: 251.0740 - val_loss: 173.3464 - val_mae: 173.3464 - 1s/epoch - 5ms/step
# Epoch 125/200
# 250/250 - 1s - loss: 260.6547 - mae: 260.6547 - val_loss: 220.8334 - val_mae: 220.8334 - 1s/epoch - 5ms/step
# Epoch 126/200
# 250/250 - 1s - loss: 250.0679 - mae: 250.0679 - val_loss: 252.7391 - val_mae: 252.7391 - 1s/epoch - 5ms/step
# Epoch 127/200
# 250/250 - 1s - loss: 261.1005 - mae: 261.1005 - val_loss: 166.2263 - val_mae: 166.2263 - 1s/epoch - 5ms/step
# Epoch 128/200
# 250/250 - 1s - loss: 245.2884 - mae: 245.2884 - val_loss: 189.7181 - val_mae: 189.7181 - 1s/epoch - 5ms/step
# Epoch 129/200
# 250/250 - 1s - loss: 260.7604 - mae: 260.7604 - val_loss: 175.0249 - val_mae: 175.0249 - 1s/epoch - 5ms/step
# Epoch 130/200
# 250/250 - 1s - loss: 253.1204 - mae: 253.1204 - val_loss: 192.2250 - val_mae: 192.2250 - 1s/epoch - 5ms/step
# Epoch 131/200
# 250/250 - 1s - loss: 251.1221 - mae: 251.1221 - val_loss: 210.3126 - val_mae: 210.3126 - 1s/epoch - 5ms/step
# Epoch 132/200
# 250/250 - 1s - loss: 257.8326 - mae: 257.8326 - val_loss: 180.2720 - val_mae: 180.2720 - 1s/epoch - 6ms/step
# Epoch 133/200
# 250/250 - 1s - loss: 244.3966 - mae: 244.3966 - val_loss: 187.1726 - val_mae: 187.1726 - 1s/epoch - 5ms/step
# Epoch 134/200
# 250/250 - 2s - loss: 253.4566 - mae: 253.4566 - val_loss: 170.2200 - val_mae: 170.2200 - 2s/epoch - 8ms/step
# Epoch 135/200
# 250/250 - 1s - loss: 251.1725 - mae: 251.1725 - val_loss: 169.7936 - val_mae: 169.7936 - 1s/epoch - 5ms/step
# Epoch 136/200
# 250/250 - 1s - loss: 245.9521 - mae: 245.9521 - val_loss: 166.3312 - val_mae: 166.3312 - 1s/epoch - 5ms/step
# Epoch 137/200
# 250/250 - 1s - loss: 245.7172 - mae: 245.7172 - val_loss: 210.1948 - val_mae: 210.1948 - 1s/epoch - 5ms/step
# Epoch 138/200
# 250/250 - 1s - loss: 257.8438 - mae: 257.8438 - val_loss: 167.4346 - val_mae: 167.4346 - 1s/epoch - 5ms/step
# Epoch 139/200
# 250/250 - 1s - loss: 255.5926 - mae: 255.5926 - val_loss: 211.6316 - val_mae: 211.6316 - 1s/epoch - 5ms/step
# Epoch 140/200
# 250/250 - 1s - loss: 248.9480 - mae: 248.9480 - val_loss: 168.3369 - val_mae: 168.3369 - 1s/epoch - 5ms/step
# Epoch 141/200
# 250/250 - 1s - loss: 247.4528 - mae: 247.4528 - val_loss: 168.4409 - val_mae: 168.4409 - 1s/epoch - 5ms/step
# Epoch 142/200
# 250/250 - 1s - loss: 258.0393 - mae: 258.0393 - val_loss: 166.4914 - val_mae: 166.4914 - 1s/epoch - 5ms/step
# Epoch 143/200
# 250/250 - 1s - loss: 251.3940 - mae: 251.3940 - val_loss: 186.7471 - val_mae: 186.7471 - 1s/epoch - 5ms/step
# Epoch 144/200
# 250/250 - 1s - loss: 247.4067 - mae: 247.4067 - val_loss: 177.3659 - val_mae: 177.3659 - 1s/epoch - 5ms/step
# Epoch 145/200
# 250/250 - 1s - loss: 250.9848 - mae: 250.9848 - val_loss: 166.7915 - val_mae: 166.7915 - 1s/epoch - 5ms/step
# Epoch 146/200
# 250/250 - 1s - loss: 253.6805 - mae: 253.6805 - val_loss: 171.5411 - val_mae: 171.5411 - 1s/epoch - 5ms/step
# Epoch 147/200
# 250/250 - 1s - loss: 248.5568 - mae: 248.5568 - val_loss: 167.1797 - val_mae: 167.1797 - 1s/epoch - 5ms/step
# Epoch 148/200
# 250/250 - 1s - loss: 255.1876 - mae: 255.1876 - val_loss: 174.5253 - val_mae: 174.5253 - 1s/epoch - 5ms/step
# Epoch 149/200
# 250/250 - 1s - loss: 246.4230 - mae: 246.4230 - val_loss: 227.5875 - val_mae: 227.5875 - 1s/epoch - 5ms/step
# Epoch 150/200
# 250/250 - 1s - loss: 250.8774 - mae: 250.8774 - val_loss: 204.7133 - val_mae: 204.7133 - 1s/epoch - 5ms/step
# Epoch 151/200
# 250/250 - 1s - loss: 250.5810 - mae: 250.5810 - val_loss: 167.2450 - val_mae: 167.2450 - 1s/epoch - 5ms/step
# Epoch 152/200
# 250/250 - 1s - loss: 249.6661 - mae: 249.6661 - val_loss: 172.2952 - val_mae: 172.2952 - 1s/epoch - 6ms/step
# Epoch 153/200
# 250/250 - 1s - loss: 257.7302 - mae: 257.7302 - val_loss: 167.0562 - val_mae: 167.0562 - 1s/epoch - 5ms/step
# Epoch 154/200
# 250/250 - 1s - loss: 263.1880 - mae: 263.1880 - val_loss: 229.5617 - val_mae: 229.5617 - 1s/epoch - 5ms/step
# Epoch 155/200
# 250/250 - 1s - loss: 255.8402 - mae: 255.8402 - val_loss: 205.7690 - val_mae: 205.7690 - 1s/epoch - 5ms/step
# Epoch 156/200
# 250/250 - 1s - loss: 252.5654 - mae: 252.5654 - val_loss: 165.9111 - val_mae: 165.9111 - 1s/epoch - 5ms/step
# Epoch 157/200
# 250/250 - 1s - loss: 262.6992 - mae: 262.6992 - val_loss: 259.1278 - val_mae: 259.1278 - 1s/epoch - 5ms/step
# Epoch 158/200
# 250/250 - 1s - loss: 257.4276 - mae: 257.4276 - val_loss: 212.0371 - val_mae: 212.0371 - 1s/epoch - 5ms/step
# Epoch 159/200
# 250/250 - 1s - loss: 255.1062 - mae: 255.1062 - val_loss: 284.2816 - val_mae: 284.2816 - 1s/epoch - 5ms/step
# Epoch 160/200
# 250/250 - 1s - loss: 258.9454 - mae: 258.9454 - val_loss: 171.6575 - val_mae: 171.6575 - 1s/epoch - 5ms/step
# Epoch 161/200
# 250/250 - 1s - loss: 250.0246 - mae: 250.0246 - val_loss: 171.5440 - val_mae: 171.5440 - 1s/epoch - 6ms/step
# Epoch 162/200
# 250/250 - 1s - loss: 254.9205 - mae: 254.9205 - val_loss: 165.7839 - val_mae: 165.7839 - 1s/epoch - 5ms/step
# Epoch 163/200
# 250/250 - 1s - loss: 248.9693 - mae: 248.9693 - val_loss: 192.4636 - val_mae: 192.4636 - 1s/epoch - 5ms/step
# Epoch 164/200
# 250/250 - 1s - loss: 255.5154 - mae: 255.5154 - val_loss: 192.0811 - val_mae: 192.0811 - 1s/epoch - 5ms/step
# Epoch 165/200
# 250/250 - 1s - loss: 265.3536 - mae: 265.3536 - val_loss: 174.1088 - val_mae: 174.1088 - 1s/epoch - 5ms/step
# Epoch 166/200
# 250/250 - 1s - loss: 254.2823 - mae: 254.2823 - val_loss: 196.0353 - val_mae: 196.0353 - 1s/epoch - 5ms/step
# Epoch 167/200
# 250/250 - 1s - loss: 246.7824 - mae: 246.7824 - val_loss: 165.9889 - val_mae: 165.9889 - 1s/epoch - 5ms/step
# Epoch 168/200
# 250/250 - 1s - loss: 254.4792 - mae: 254.4792 - val_loss: 165.8488 - val_mae: 165.8488 - 1s/epoch - 5ms/step
# Epoch 169/200
# 250/250 - 1s - loss: 254.0230 - mae: 254.0230 - val_loss: 168.6489 - val_mae: 168.6489 - 1s/epoch - 5ms/step
# Epoch 170/200
# 250/250 - 1s - loss: 253.5609 - mae: 253.5609 - val_loss: 171.9417 - val_mae: 171.9417 - 1s/epoch - 5ms/step
# Epoch 171/200
# 250/250 - 1s - loss: 253.6234 - mae: 253.6234 - val_loss: 219.2445 - val_mae: 219.2445 - 1s/epoch - 5ms/step
# Epoch 172/200
# 250/250 - 1s - loss: 248.2426 - mae: 248.2426 - val_loss: 207.5008 - val_mae: 207.5008 - 1s/epoch - 5ms/step
# Epoch 173/200
# 250/250 - 1s - loss: 245.8478 - mae: 245.8478 - val_loss: 213.1848 - val_mae: 213.1848 - 1s/epoch - 5ms/step
# Epoch 174/200
# 250/250 - 1s - loss: 255.7798 - mae: 255.7798 - val_loss: 166.0255 - val_mae: 166.0255 - 1s/epoch - 6ms/step
# Epoch 175/200
# 250/250 - 1s - loss: 257.1267 - mae: 257.1267 - val_loss: 211.1163 - val_mae: 211.1163 - 1s/epoch - 5ms/step
# Epoch 176/200
# 250/250 - 1s - loss: 258.9608 - mae: 258.9608 - val_loss: 174.9151 - val_mae: 174.9151 - 1s/epoch - 5ms/step
# Epoch 177/200
# 250/250 - 1s - loss: 249.7401 - mae: 249.7401 - val_loss: 201.4181 - val_mae: 201.4181 - 1s/epoch - 5ms/step
# Epoch 178/200
# 250/250 - 1s - loss: 256.6522 - mae: 256.6522 - val_loss: 167.2633 - val_mae: 167.2633 - 1s/epoch - 5ms/step
# Epoch 179/200
# 250/250 - 1s - loss: 246.2433 - mae: 246.2433 - val_loss: 168.2027 - val_mae: 168.2027 - 1s/epoch - 6ms/step
# Epoch 180/200
# 250/250 - 1s - loss: 253.4624 - mae: 253.4624 - val_loss: 196.0575 - val_mae: 196.0575 - 1s/epoch - 5ms/step
# Epoch 181/200
# 250/250 - 1s - loss: 246.7346 - mae: 246.7346 - val_loss: 173.7294 - val_mae: 173.7294 - 1s/epoch - 5ms/step
# Epoch 182/200
# 250/250 - 1s - loss: 245.2327 - mae: 245.2327 - val_loss: 182.0125 - val_mae: 182.0125 - 1s/epoch - 5ms/step
# Epoch 183/200
# 250/250 - 1s - loss: 250.9848 - mae: 250.9848 - val_loss: 165.4921 - val_mae: 165.4921 - 1s/epoch - 5ms/step
# Epoch 184/200
# 250/250 - 1s - loss: 251.0425 - mae: 251.0425 - val_loss: 178.9285 - val_mae: 178.9285 - 1s/epoch - 5ms/step
# Epoch 185/200
# 250/250 - 1s - loss: 253.0554 - mae: 253.0554 - val_loss: 181.8691 - val_mae: 181.8691 - 1s/epoch - 5ms/step
# Epoch 186/200
# 250/250 - 1s - loss: 252.3404 - mae: 252.3404 - val_loss: 169.5667 - val_mae: 169.5667 - 1s/epoch - 5ms/step
# Epoch 187/200
# 250/250 - 1s - loss: 254.3018 - mae: 254.3018 - val_loss: 188.7322 - val_mae: 188.7322 - 1s/epoch - 5ms/step
# Epoch 188/200
# 250/250 - 1s - loss: 259.2159 - mae: 259.2159 - val_loss: 189.2804 - val_mae: 189.2804 - 1s/epoch - 6ms/step
# Epoch 189/200
# 250/250 - 1s - loss: 249.5154 - mae: 249.5154 - val_loss: 170.8818 - val_mae: 170.8818 - 1s/epoch - 5ms/step
# Epoch 190/200
# 250/250 - 1s - loss: 250.8591 - mae: 250.8591 - val_loss: 179.8046 - val_mae: 179.8046 - 1s/epoch - 5ms/step
# Epoch 191/200
# 250/250 - 1s - loss: 258.5761 - mae: 258.5761 - val_loss: 167.5944 - val_mae: 167.5944 - 1s/epoch - 5ms/step
# Epoch 192/200
# 250/250 - 1s - loss: 251.7466 - mae: 251.7466 - val_loss: 165.9413 - val_mae: 165.9413 - 1s/epoch - 5ms/step
# Epoch 193/200
# 250/250 - 1s - loss: 256.3510 - mae: 256.3510 - val_loss: 206.0829 - val_mae: 206.0829 - 1s/epoch - 5ms/step
# Epoch 194/200
# 250/250 - 1s - loss: 248.4963 - mae: 248.4963 - val_loss: 178.8945 - val_mae: 178.8945 - 1s/epoch - 5ms/step
# Epoch 195/200
# 250/250 - 1s - loss: 250.6558 - mae: 250.6558 - val_loss: 165.4121 - val_mae: 165.4121 - 1s/epoch - 5ms/step
# Epoch 196/200
# 250/250 - 1s - loss: 244.9770 - mae: 244.9770 - val_loss: 165.4194 - val_mae: 165.4194 - 1s/epoch - 5ms/step
# Epoch 197/200
# 250/250 - 1s - loss: 254.1616 - mae: 254.1616 - val_loss: 172.4731 - val_mae: 172.4731 - 1s/epoch - 5ms/step
# Epoch 198/200
# 250/250 - 1s - loss: 258.1375 - mae: 258.1375 - val_loss: 195.0948 - val_mae: 195.0948 - 1s/epoch - 5ms/step
# Epoch 199/200
# 250/250 - 1s - loss: 253.2829 - mae: 253.2829 - val_loss: 181.4040 - val_mae: 181.4040 - 1s/epoch - 5ms/step
# Epoch 200/200
# 250/250 - 1s - loss: 246.6785 - mae: 246.6785 - val_loss: 170.1183 - val_mae: 170.1183 - 1s/epoch - 5ms/step
# 손실 함수: 170.1182861328125 MAE: 170.1182861328125
# 4/4 [==============================] - 0s 4ms/step
# 평균절댓값백분율오차(MAPE): [0.02035679]

# %%
# 다중 채널 비트코인 가격 예측

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 코인데스크 사이트에서 1년치 비트코인 가격 데이터 읽기
f=open("/content/BTC_USD_2019-02-28_2020-02-27-CoinDesk.csv","r")
coindesk_data=pd.read_csv(f,header=0)
seq=coindesk_data[['Closing Price (USD)','24h Open (USD)','24h High (USD)','24h Low (USD)']].to_numpy() # 종가, 시가, 고가, 저가를 모두 취함

# 시계열 데이터를 윈도우 단위로 자르는 함수
def seq2dataset(seq,window,horizon):
    X=[]; Y=[]
    for i in range(len(seq)-(window+horizon)+1):
        x=seq[i:(i+window)]
        y=(seq[i+window+horizon-1])
        X.append(x); Y.append(y)
    return np.array(X), np.array(Y)

w=7 # 윈도우 크기
h=1 # 수평선 계수

X,Y = seq2dataset(seq,w,h)
print(X.shape,Y.shape)
print(X[0],Y[0])

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# 훈련 집합과 테스트 집합으로 분할
split=int(len(X)*0.7)
x_train=X[0:split]; y_train=Y[0:split]
x_test=X[split:]; y_test=Y[split:]

# LSTM 모델의 설계와 학습
model = Sequential()
model.add(LSTM(units=128,activation='relu',input_shape=x_train[0].shape))
model.add(Dense(4))
model.compile(loss='mae',optimizer='adam',metrics=['mae'])
hist=model.fit(x_train,y_train,epochs=200,batch_size=1,validation_data=(x_test,y_test),verbose=2)

# LSTM 모델 평가
ev=model.evaluate(x_test,y_test,verbose=0)
print("손실 함수:",ev[0],"MAE:",ev[1])

# LSTM 모델로 예측 수행
pred=model.predict(x_test) # LSTM
print("LSTM 평균절댓값백분율오차(MAPE):",sum(abs(y_test-pred)/y_test)/len(x_test))

# 학습 곡선
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('Model mae')
plt.ylabel('mae')
plt.xlabel('Epoch')
plt.ylim([100,600])
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (358, 7, 4) (358, 4)
# [[3772.93633533 3796.63728431 3824.16587937 3666.52401643]
#  [3799.67854295 3773.44146075 3879.23118467 3753.80002246]
#  [3811.61197937 3799.36702601 3840.04482307 3788.91849833]
#  [3804.41917011 3806.69151279 3819.19435612 3759.40921647]
#  [3782.66410112 3807.84575592 3818.69548135 3766.24204823]
#  [3689.86289319 3783.35506344 3804.35361623 3663.47774336]
#  [3832.08088473 3701.04987103 3866.71870424 3688.69715385]] [3848.95636968 3832.59242908 3881.96576977 3802.51605364]
# Epoch 1/200
# 250/250 - 2s - loss: 1218.0557 - mae: 1218.0557 - val_loss: 416.9376 - val_mae: 416.9376 - 2s/epoch - 9ms/step
# Epoch 2/200
# 250/250 - 1s - loss: 531.6849 - mae: 531.6849 - val_loss: 425.2707 - val_mae: 425.2707 - 1s/epoch - 6ms/step
# Epoch 3/200
# 250/250 - 1s - loss: 535.6362 - mae: 535.6362 - val_loss: 338.2639 - val_mae: 338.2639 - 1s/epoch - 5ms/step
# Epoch 4/200
# 250/250 - 1s - loss: 518.6684 - mae: 518.6684 - val_loss: 480.0092 - val_mae: 480.0092 - 1s/epoch - 5ms/step
# Epoch 5/200
# 250/250 - 1s - loss: 513.8496 - mae: 513.8496 - val_loss: 335.7621 - val_mae: 335.7621 - 1s/epoch - 5ms/step
# Epoch 6/200
# 250/250 - 1s - loss: 510.6346 - mae: 510.6346 - val_loss: 574.7362 - val_mae: 574.7362 - 1s/epoch - 5ms/step
# Epoch 7/200
# 250/250 - 1s - loss: 515.0671 - mae: 515.0671 - val_loss: 396.3887 - val_mae: 396.3887 - 1s/epoch - 5ms/step
# Epoch 8/200
# 250/250 - 1s - loss: 494.5442 - mae: 494.5442 - val_loss: 310.7322 - val_mae: 310.7322 - 1s/epoch - 5ms/step
# Epoch 9/200
# 250/250 - 1s - loss: 496.5297 - mae: 496.5297 - val_loss: 295.8369 - val_mae: 295.8369 - 1s/epoch - 5ms/step
# Epoch 10/200
# 250/250 - 1s - loss: 481.7638 - mae: 481.7638 - val_loss: 290.6778 - val_mae: 290.6778 - 1s/epoch - 5ms/step
# Epoch 11/200
# 250/250 - 1s - loss: 475.0377 - mae: 475.0377 - val_loss: 734.4202 - val_mae: 734.4202 - 1s/epoch - 5ms/step
# Epoch 12/200
# 250/250 - 1s - loss: 477.5490 - mae: 477.5490 - val_loss: 305.1130 - val_mae: 305.1130 - 1s/epoch - 5ms/step
# Epoch 13/200
# 250/250 - 1s - loss: 440.8358 - mae: 440.8358 - val_loss: 253.7015 - val_mae: 253.7015 - 1s/epoch - 5ms/step
# Epoch 14/200
# 250/250 - 1s - loss: 410.1375 - mae: 410.1375 - val_loss: 305.3502 - val_mae: 305.3502 - 1s/epoch - 5ms/step
# Epoch 15/200
# 250/250 - 1s - loss: 386.8051 - mae: 386.8051 - val_loss: 238.0678 - val_mae: 238.0678 - 1s/epoch - 5ms/step
# Epoch 16/200
# 250/250 - 1s - loss: 419.8223 - mae: 419.8223 - val_loss: 500.0665 - val_mae: 500.0665 - 1s/epoch - 5ms/step
# Epoch 17/200
# 250/250 - 1s - loss: 606.5161 - mae: 606.5161 - val_loss: 258.9826 - val_mae: 258.9826 - 1s/epoch - 5ms/step
# Epoch 18/200
# 250/250 - 1s - loss: 896.5345 - mae: 896.5345 - val_loss: 394.4859 - val_mae: 394.4859 - 1s/epoch - 5ms/step
# Epoch 19/200
# 250/250 - 1s - loss: 488.4048 - mae: 488.4048 - val_loss: 293.1836 - val_mae: 293.1836 - 1s/epoch - 5ms/step
# Epoch 20/200
# 250/250 - 1s - loss: 464.1105 - mae: 464.1105 - val_loss: 495.9187 - val_mae: 495.9187 - 1s/epoch - 5ms/step
# Epoch 21/200
# 250/250 - 1s - loss: 452.3727 - mae: 452.3727 - val_loss: 336.1047 - val_mae: 336.1047 - 1s/epoch - 5ms/step
# Epoch 22/200
# 250/250 - 1s - loss: 419.6599 - mae: 419.6599 - val_loss: 301.5130 - val_mae: 301.5130 - 1s/epoch - 5ms/step
# Epoch 23/200
# 250/250 - 1s - loss: 427.3963 - mae: 427.3963 - val_loss: 278.0635 - val_mae: 278.0635 - 1s/epoch - 5ms/step
# Epoch 24/200
# 250/250 - 1s - loss: 418.2071 - mae: 418.2071 - val_loss: 270.9137 - val_mae: 270.9137 - 1s/epoch - 5ms/step
# Epoch 25/200
# 250/250 - 1s - loss: 424.2288 - mae: 424.2288 - val_loss: 538.6895 - val_mae: 538.6895 - 1s/epoch - 5ms/step
# Epoch 26/200
# 250/250 - 1s - loss: 424.2397 - mae: 424.2397 - val_loss: 266.2389 - val_mae: 266.2389 - 1s/epoch - 6ms/step
# Epoch 27/200
# 250/250 - 1s - loss: 393.8934 - mae: 393.8934 - val_loss: 262.5245 - val_mae: 262.5245 - 1s/epoch - 5ms/step
# Epoch 28/200
# 250/250 - 1s - loss: 386.2514 - mae: 386.2514 - val_loss: 294.0263 - val_mae: 294.0263 - 1s/epoch - 5ms/step
# Epoch 29/200
# 250/250 - 1s - loss: 401.5861 - mae: 401.5861 - val_loss: 333.5020 - val_mae: 333.5020 - 1s/epoch - 6ms/step
# Epoch 30/200
# 250/250 - 1s - loss: 381.8923 - mae: 381.8923 - val_loss: 349.0092 - val_mae: 349.0092 - 1s/epoch - 5ms/step
# Epoch 31/200
# 250/250 - 1s - loss: 352.0529 - mae: 352.0529 - val_loss: 257.0534 - val_mae: 257.0534 - 1s/epoch - 5ms/step
# Epoch 32/200
# 250/250 - 1s - loss: 355.4202 - mae: 355.4202 - val_loss: 236.1970 - val_mae: 236.1970 - 1s/epoch - 5ms/step
# Epoch 33/200
# 250/250 - 1s - loss: 340.5594 - mae: 340.5594 - val_loss: 251.3899 - val_mae: 251.3899 - 1s/epoch - 5ms/step
# Epoch 34/200
# 250/250 - 1s - loss: 341.8872 - mae: 341.8872 - val_loss: 233.7909 - val_mae: 233.7909 - 1s/epoch - 5ms/step
# Epoch 35/200
# 250/250 - 1s - loss: 336.5793 - mae: 336.5793 - val_loss: 206.7428 - val_mae: 206.7428 - 1s/epoch - 5ms/step
# Epoch 36/200
# 250/250 - 1s - loss: 347.2357 - mae: 347.2357 - val_loss: 212.5702 - val_mae: 212.5702 - 1s/epoch - 5ms/step
# Epoch 37/200
# 250/250 - 1s - loss: 324.0205 - mae: 324.0205 - val_loss: 210.0049 - val_mae: 210.0049 - 1s/epoch - 5ms/step
# Epoch 38/200
# 250/250 - 1s - loss: 302.3289 - mae: 302.3289 - val_loss: 238.7338 - val_mae: 238.7338 - 1s/epoch - 5ms/step
# Epoch 39/200
# 250/250 - 1s - loss: 310.5482 - mae: 310.5482 - val_loss: 192.6683 - val_mae: 192.6683 - 1s/epoch - 5ms/step
# Epoch 40/200
# 250/250 - 1s - loss: 301.1242 - mae: 301.1242 - val_loss: 216.1776 - val_mae: 216.1776 - 1s/epoch - 5ms/step
# Epoch 41/200
# 250/250 - 1s - loss: 287.1844 - mae: 287.1844 - val_loss: 208.3120 - val_mae: 208.3120 - 1s/epoch - 5ms/step
# Epoch 42/200
# 250/250 - 1s - loss: 294.6661 - mae: 294.6661 - val_loss: 222.2758 - val_mae: 222.2758 - 1s/epoch - 5ms/step
# Epoch 43/200
# 250/250 - 1s - loss: 279.2394 - mae: 279.2394 - val_loss: 193.7339 - val_mae: 193.7339 - 1s/epoch - 5ms/step
# Epoch 44/200
# 250/250 - 1s - loss: 276.5803 - mae: 276.5803 - val_loss: 186.6616 - val_mae: 186.6616 - 1s/epoch - 6ms/step
# Epoch 45/200
# 250/250 - 1s - loss: 284.8124 - mae: 284.8124 - val_loss: 285.9340 - val_mae: 285.9340 - 1s/epoch - 5ms/step
# Epoch 46/200
# 250/250 - 1s - loss: 260.3538 - mae: 260.3538 - val_loss: 213.0825 - val_mae: 213.0825 - 1s/epoch - 5ms/step
# Epoch 47/200
# 250/250 - 1s - loss: 257.2306 - mae: 257.2306 - val_loss: 178.8091 - val_mae: 178.8091 - 1s/epoch - 5ms/step
# Epoch 48/200
# 250/250 - 1s - loss: 255.2534 - mae: 255.2534 - val_loss: 220.9446 - val_mae: 220.9446 - 1s/epoch - 5ms/step
# Epoch 49/200
# 250/250 - 1s - loss: 254.5160 - mae: 254.5160 - val_loss: 381.3240 - val_mae: 381.3240 - 1s/epoch - 5ms/step
# Epoch 50/200
# 250/250 - 1s - loss: 253.1041 - mae: 253.1041 - val_loss: 172.7200 - val_mae: 172.7200 - 1s/epoch - 5ms/step
# Epoch 51/200
# 250/250 - 1s - loss: 253.1561 - mae: 253.1561 - val_loss: 159.9792 - val_mae: 159.9792 - 1s/epoch - 6ms/step
# Epoch 52/200
# 250/250 - 1s - loss: 247.8729 - mae: 247.8729 - val_loss: 152.0018 - val_mae: 152.0018 - 1s/epoch - 5ms/step
# Epoch 53/200
# 250/250 - 1s - loss: 244.8635 - mae: 244.8635 - val_loss: 174.7205 - val_mae: 174.7205 - 1s/epoch - 5ms/step
# Epoch 54/200
# 250/250 - 1s - loss: 238.4784 - mae: 238.4784 - val_loss: 156.5416 - val_mae: 156.5416 - 1s/epoch - 6ms/step
# Epoch 55/200
# 250/250 - 1s - loss: 238.5229 - mae: 238.5229 - val_loss: 190.8809 - val_mae: 190.8809 - 1s/epoch - 6ms/step
# Epoch 56/200
# 250/250 - 1s - loss: 226.4315 - mae: 226.4315 - val_loss: 190.6481 - val_mae: 190.6481 - 1s/epoch - 6ms/step
# Epoch 57/200
# 250/250 - 1s - loss: 231.1724 - mae: 231.1724 - val_loss: 153.8260 - val_mae: 153.8260 - 1s/epoch - 5ms/step
# Epoch 58/200
# 250/250 - 1s - loss: 228.0964 - mae: 228.0964 - val_loss: 154.4939 - val_mae: 154.4939 - 1s/epoch - 5ms/step
# Epoch 59/200
# 250/250 - 1s - loss: 223.7650 - mae: 223.7650 - val_loss: 147.8642 - val_mae: 147.8642 - 1s/epoch - 5ms/step
# Epoch 60/200
# 250/250 - 1s - loss: 219.5836 - mae: 219.5836 - val_loss: 193.5195 - val_mae: 193.5195 - 1s/epoch - 5ms/step
# Epoch 61/200
# 250/250 - 1s - loss: 221.8295 - mae: 221.8295 - val_loss: 142.0552 - val_mae: 142.0552 - 1s/epoch - 5ms/step
# Epoch 62/200
# 250/250 - 1s - loss: 217.9548 - mae: 217.9548 - val_loss: 181.7088 - val_mae: 181.7088 - 1s/epoch - 5ms/step
# Epoch 63/200
# 250/250 - 1s - loss: 216.4428 - mae: 216.4428 - val_loss: 201.7862 - val_mae: 201.7862 - 1s/epoch - 5ms/step
# Epoch 64/200
# 250/250 - 1s - loss: 211.5141 - mae: 211.5141 - val_loss: 136.1758 - val_mae: 136.1758 - 1s/epoch - 5ms/step
# Epoch 65/200
# 250/250 - 1s - loss: 210.7828 - mae: 210.7828 - val_loss: 137.4364 - val_mae: 137.4364 - 1s/epoch - 5ms/step
# Epoch 66/200
# 250/250 - 1s - loss: 226.8326 - mae: 226.8326 - val_loss: 139.4498 - val_mae: 139.4498 - 1s/epoch - 5ms/step
# Epoch 67/200
# 250/250 - 1s - loss: 201.0874 - mae: 201.0874 - val_loss: 147.0310 - val_mae: 147.0310 - 1s/epoch - 5ms/step
# Epoch 68/200
# 250/250 - 1s - loss: 206.8607 - mae: 206.8607 - val_loss: 135.2577 - val_mae: 135.2577 - 1s/epoch - 6ms/step
# Epoch 69/200
# 250/250 - 1s - loss: 199.9629 - mae: 199.9629 - val_loss: 136.5646 - val_mae: 136.5646 - 1s/epoch - 5ms/step
# Epoch 70/200
# 250/250 - 1s - loss: 198.5585 - mae: 198.5585 - val_loss: 137.7238 - val_mae: 137.7238 - 1s/epoch - 5ms/step
# Epoch 71/200
# 250/250 - 1s - loss: 196.4631 - mae: 196.4631 - val_loss: 128.6272 - val_mae: 128.6272 - 1s/epoch - 5ms/step
# Epoch 72/200
# 250/250 - 1s - loss: 214.0974 - mae: 214.0974 - val_loss: 148.5850 - val_mae: 148.5850 - 1s/epoch - 5ms/step
# Epoch 73/200
# 250/250 - 1s - loss: 207.0366 - mae: 207.0366 - val_loss: 153.4440 - val_mae: 153.4440 - 1s/epoch - 5ms/step
# Epoch 74/200
# 250/250 - 1s - loss: 207.8139 - mae: 207.8139 - val_loss: 154.2250 - val_mae: 154.2250 - 1s/epoch - 5ms/step
# Epoch 75/200
# 250/250 - 1s - loss: 205.6733 - mae: 205.6733 - val_loss: 187.3659 - val_mae: 187.3659 - 1s/epoch - 5ms/step
# Epoch 76/200
# 250/250 - 1s - loss: 199.3545 - mae: 199.3545 - val_loss: 135.2095 - val_mae: 135.2095 - 1s/epoch - 5ms/step
# Epoch 77/200
# 250/250 - 1s - loss: 193.2321 - mae: 193.2321 - val_loss: 148.3684 - val_mae: 148.3684 - 1s/epoch - 6ms/step
# Epoch 78/200
# 250/250 - 1s - loss: 195.1494 - mae: 195.1494 - val_loss: 135.5773 - val_mae: 135.5773 - 1s/epoch - 5ms/step
# Epoch 79/200
# 250/250 - 1s - loss: 194.9569 - mae: 194.9569 - val_loss: 144.8696 - val_mae: 144.8696 - 1s/epoch - 5ms/step
# Epoch 80/200
# 250/250 - 1s - loss: 186.8728 - mae: 186.8728 - val_loss: 130.7308 - val_mae: 130.7308 - 1s/epoch - 5ms/step
# Epoch 81/200
# 250/250 - 1s - loss: 192.4439 - mae: 192.4439 - val_loss: 134.6448 - val_mae: 134.6448 - 1s/epoch - 6ms/step
# Epoch 82/200
# 250/250 - 1s - loss: 194.5005 - mae: 194.5005 - val_loss: 121.6366 - val_mae: 121.6366 - 1s/epoch - 5ms/step
# Epoch 83/200
# 250/250 - 1s - loss: 193.4518 - mae: 193.4518 - val_loss: 126.4153 - val_mae: 126.4153 - 1s/epoch - 5ms/step
# Epoch 84/200
# 250/250 - 1s - loss: 215.8288 - mae: 215.8288 - val_loss: 133.1172 - val_mae: 133.1172 - 1s/epoch - 5ms/step
# Epoch 85/200
# 250/250 - 1s - loss: 191.9130 - mae: 191.9130 - val_loss: 161.7201 - val_mae: 161.7201 - 1s/epoch - 5ms/step
# Epoch 86/200
# 250/250 - 1s - loss: 185.1903 - mae: 185.1903 - val_loss: 127.4318 - val_mae: 127.4318 - 1s/epoch - 5ms/step
# Epoch 87/200
# 250/250 - 1s - loss: 183.2393 - mae: 183.2393 - val_loss: 120.7974 - val_mae: 120.7974 - 1s/epoch - 5ms/step
# Epoch 88/200
# 250/250 - 1s - loss: 184.1668 - mae: 184.1668 - val_loss: 157.3596 - val_mae: 157.3596 - 1s/epoch - 5ms/step
# Epoch 89/200
# 250/250 - 1s - loss: 185.7139 - mae: 185.7139 - val_loss: 132.1898 - val_mae: 132.1898 - 1s/epoch - 5ms/step
# Epoch 90/200
# 250/250 - 1s - loss: 186.1966 - mae: 186.1966 - val_loss: 141.6999 - val_mae: 141.6999 - 1s/epoch - 5ms/step
# Epoch 91/200
# 250/250 - 1s - loss: 184.2314 - mae: 184.2314 - val_loss: 154.5918 - val_mae: 154.5918 - 1s/epoch - 5ms/step
# Epoch 92/200
# 250/250 - 1s - loss: 187.0167 - mae: 187.0167 - val_loss: 134.6394 - val_mae: 134.6394 - 1s/epoch - 5ms/step
# Epoch 93/200
# 250/250 - 1s - loss: 179.8804 - mae: 179.8804 - val_loss: 138.8305 - val_mae: 138.8305 - 1s/epoch - 6ms/step
# Epoch 94/200
# 250/250 - 1s - loss: 182.5788 - mae: 182.5788 - val_loss: 143.6429 - val_mae: 143.6429 - 1s/epoch - 5ms/step
# Epoch 95/200
# 250/250 - 1s - loss: 187.2060 - mae: 187.2060 - val_loss: 129.0648 - val_mae: 129.0648 - 1s/epoch - 5ms/step
# Epoch 96/200
# 250/250 - 1s - loss: 183.2968 - mae: 183.2968 - val_loss: 114.5888 - val_mae: 114.5888 - 1s/epoch - 5ms/step
# Epoch 97/200
# 250/250 - 1s - loss: 181.2193 - mae: 181.2193 - val_loss: 144.5671 - val_mae: 144.5671 - 1s/epoch - 5ms/step
# Epoch 98/200
# 250/250 - 1s - loss: 188.5629 - mae: 188.5629 - val_loss: 138.3299 - val_mae: 138.3299 - 1s/epoch - 5ms/step
# Epoch 99/200
# 250/250 - 1s - loss: 185.0816 - mae: 185.0816 - val_loss: 126.1164 - val_mae: 126.1164 - 1s/epoch - 5ms/step
# Epoch 100/200
# 250/250 - 1s - loss: 181.8785 - mae: 181.8785 - val_loss: 115.8856 - val_mae: 115.8856 - 1s/epoch - 6ms/step
# Epoch 101/200
# 250/250 - 1s - loss: 184.7734 - mae: 184.7734 - val_loss: 133.7121 - val_mae: 133.7121 - 1s/epoch - 5ms/step
# Epoch 102/200
# 250/250 - 1s - loss: 186.0120 - mae: 186.0120 - val_loss: 117.0771 - val_mae: 117.0771 - 1s/epoch - 5ms/step
# Epoch 103/200
# 250/250 - 1s - loss: 182.9684 - mae: 182.9684 - val_loss: 180.3258 - val_mae: 180.3258 - 1s/epoch - 6ms/step
# Epoch 104/200
# 250/250 - 1s - loss: 180.0090 - mae: 180.0090 - val_loss: 130.8275 - val_mae: 130.8275 - 1s/epoch - 5ms/step
# Epoch 105/200
# 250/250 - 1s - loss: 173.9940 - mae: 173.9940 - val_loss: 122.3977 - val_mae: 122.3977 - 1s/epoch - 5ms/step
# Epoch 106/200
# 250/250 - 1s - loss: 178.2283 - mae: 178.2283 - val_loss: 113.0443 - val_mae: 113.0443 - 1s/epoch - 5ms/step
# Epoch 107/200
# 250/250 - 1s - loss: 178.1387 - mae: 178.1387 - val_loss: 121.8850 - val_mae: 121.8850 - 1s/epoch - 5ms/step
# Epoch 108/200
# 250/250 - 1s - loss: 177.4739 - mae: 177.4739 - val_loss: 190.3315 - val_mae: 190.3315 - 1s/epoch - 5ms/step
# Epoch 109/200
# 250/250 - 1s - loss: 178.1243 - mae: 178.1243 - val_loss: 135.9572 - val_mae: 135.9572 - 1s/epoch - 5ms/step
# Epoch 110/200
# 250/250 - 1s - loss: 175.4386 - mae: 175.4386 - val_loss: 145.6729 - val_mae: 145.6729 - 1s/epoch - 5ms/step
# Epoch 111/200
# 250/250 - 1s - loss: 178.4601 - mae: 178.4601 - val_loss: 126.8794 - val_mae: 126.8794 - 1s/epoch - 6ms/step
# Epoch 112/200
# 250/250 - 1s - loss: 174.6084 - mae: 174.6084 - val_loss: 121.8895 - val_mae: 121.8895 - 1s/epoch - 5ms/step
# Epoch 113/200
# 250/250 - 1s - loss: 175.3231 - mae: 175.3231 - val_loss: 128.4869 - val_mae: 128.4869 - 1s/epoch - 5ms/step
# Epoch 114/200
# 250/250 - 1s - loss: 179.4865 - mae: 179.4865 - val_loss: 127.8825 - val_mae: 127.8825 - 1s/epoch - 5ms/step
# Epoch 115/200
# 250/250 - 1s - loss: 180.6461 - mae: 180.6461 - val_loss: 123.8134 - val_mae: 123.8134 - 1s/epoch - 5ms/step
# Epoch 116/200
# 250/250 - 1s - loss: 177.5761 - mae: 177.5761 - val_loss: 114.0418 - val_mae: 114.0418 - 1s/epoch - 6ms/step
# Epoch 117/200
# 250/250 - 1s - loss: 180.3591 - mae: 180.3591 - val_loss: 114.6851 - val_mae: 114.6851 - 1s/epoch - 5ms/step
# Epoch 118/200
# 250/250 - 1s - loss: 174.9309 - mae: 174.9309 - val_loss: 139.9057 - val_mae: 139.9057 - 1s/epoch - 6ms/step
# Epoch 119/200
# 250/250 - 1s - loss: 176.0333 - mae: 176.0333 - val_loss: 112.4048 - val_mae: 112.4048 - 1s/epoch - 5ms/step
# Epoch 120/200
# 250/250 - 1s - loss: 180.7533 - mae: 180.7533 - val_loss: 139.3790 - val_mae: 139.3790 - 1s/epoch - 6ms/step
# Epoch 121/200
# 250/250 - 1s - loss: 175.8009 - mae: 175.8009 - val_loss: 114.6750 - val_mae: 114.6750 - 1s/epoch - 6ms/step
# Epoch 122/200
# 250/250 - 1s - loss: 175.7420 - mae: 175.7420 - val_loss: 120.9847 - val_mae: 120.9847 - 1s/epoch - 6ms/step
# Epoch 123/200
# 250/250 - 1s - loss: 172.7134 - mae: 172.7134 - val_loss: 111.0066 - val_mae: 111.0066 - 1s/epoch - 5ms/step
# Epoch 124/200
# 250/250 - 1s - loss: 175.5163 - mae: 175.5163 - val_loss: 113.0094 - val_mae: 113.0094 - 1s/epoch - 6ms/step
# Epoch 125/200
# 250/250 - 1s - loss: 173.9725 - mae: 173.9725 - val_loss: 128.6857 - val_mae: 128.6857 - 1s/epoch - 5ms/step
# Epoch 126/200
# 250/250 - 1s - loss: 173.5930 - mae: 173.5930 - val_loss: 110.1967 - val_mae: 110.1967 - 1s/epoch - 5ms/step
# Epoch 127/200
# 250/250 - 1s - loss: 174.0635 - mae: 174.0635 - val_loss: 118.6488 - val_mae: 118.6488 - 1s/epoch - 5ms/step
# Epoch 128/200
# 250/250 - 1s - loss: 177.8432 - mae: 177.8432 - val_loss: 114.3797 - val_mae: 114.3797 - 1s/epoch - 5ms/step
# Epoch 129/200
# 250/250 - 1s - loss: 172.4238 - mae: 172.4238 - val_loss: 114.9419 - val_mae: 114.9419 - 1s/epoch - 5ms/step
# Epoch 130/200
# 250/250 - 1s - loss: 175.3001 - mae: 175.3001 - val_loss: 175.2012 - val_mae: 175.2012 - 1s/epoch - 5ms/step
# Epoch 131/200
# 250/250 - 1s - loss: 174.5322 - mae: 174.5322 - val_loss: 119.9266 - val_mae: 119.9266 - 1s/epoch - 5ms/step
# Epoch 132/200
# 250/250 - 1s - loss: 172.5714 - mae: 172.5714 - val_loss: 139.7690 - val_mae: 139.7690 - 1s/epoch - 6ms/step
# Epoch 133/200
# 250/250 - 1s - loss: 168.9853 - mae: 168.9853 - val_loss: 124.6749 - val_mae: 124.6749 - 1s/epoch - 5ms/step
# Epoch 134/200
# 250/250 - 1s - loss: 178.7878 - mae: 178.7878 - val_loss: 119.1633 - val_mae: 119.1633 - 1s/epoch - 5ms/step
# Epoch 135/200
# 250/250 - 1s - loss: 182.1785 - mae: 182.1785 - val_loss: 128.0615 - val_mae: 128.0615 - 1s/epoch - 5ms/step
# Epoch 136/200
# 250/250 - 1s - loss: 172.4595 - mae: 172.4595 - val_loss: 149.1437 - val_mae: 149.1437 - 1s/epoch - 5ms/step
# Epoch 137/200
# 250/250 - 1s - loss: 172.8710 - mae: 172.8710 - val_loss: 163.2002 - val_mae: 163.2002 - 1s/epoch - 5ms/step
# Epoch 138/200
# 250/250 - 1s - loss: 169.4960 - mae: 169.4960 - val_loss: 113.1951 - val_mae: 113.1951 - 1s/epoch - 6ms/step
# Epoch 139/200
# 250/250 - 1s - loss: 170.5983 - mae: 170.5983 - val_loss: 136.0733 - val_mae: 136.0733 - 1s/epoch - 5ms/step
# Epoch 140/200
# 250/250 - 1s - loss: 170.3012 - mae: 170.3012 - val_loss: 127.5738 - val_mae: 127.5738 - 1s/epoch - 6ms/step
# Epoch 141/200
# 250/250 - 1s - loss: 172.2220 - mae: 172.2220 - val_loss: 145.1118 - val_mae: 145.1118 - 1s/epoch - 6ms/step
# Epoch 142/200
# 250/250 - 1s - loss: 174.2168 - mae: 174.2168 - val_loss: 113.8034 - val_mae: 113.8034 - 1s/epoch - 5ms/step
# Epoch 143/200
# 250/250 - 1s - loss: 178.0186 - mae: 178.0186 - val_loss: 129.4670 - val_mae: 129.4670 - 1s/epoch - 5ms/step
# Epoch 144/200
# 250/250 - 1s - loss: 173.2824 - mae: 173.2824 - val_loss: 133.6117 - val_mae: 133.6117 - 1s/epoch - 5ms/step
# Epoch 145/200
# 250/250 - 1s - loss: 173.5509 - mae: 173.5509 - val_loss: 127.8523 - val_mae: 127.8523 - 1s/epoch - 5ms/step
# Epoch 146/200
# 250/250 - 1s - loss: 174.5199 - mae: 174.5199 - val_loss: 147.8095 - val_mae: 147.8095 - 1s/epoch - 5ms/step
# Epoch 147/200
# 250/250 - 1s - loss: 171.4713 - mae: 171.4713 - val_loss: 134.0779 - val_mae: 134.0779 - 1s/epoch - 5ms/step
# Epoch 148/200
# 250/250 - 1s - loss: 170.7110 - mae: 170.7110 - val_loss: 175.7382 - val_mae: 175.7382 - 1s/epoch - 5ms/step
# Epoch 149/200
# 250/250 - 1s - loss: 174.4743 - mae: 174.4743 - val_loss: 133.2895 - val_mae: 133.2895 - 1s/epoch - 5ms/step
# Epoch 150/200
# 250/250 - 1s - loss: 171.1845 - mae: 171.1845 - val_loss: 122.9198 - val_mae: 122.9198 - 1s/epoch - 5ms/step
# Epoch 151/200
# 250/250 - 1s - loss: 168.7523 - mae: 168.7523 - val_loss: 126.9938 - val_mae: 126.9938 - 1s/epoch - 5ms/step
# Epoch 152/200
# 250/250 - 1s - loss: 174.8226 - mae: 174.8226 - val_loss: 112.7019 - val_mae: 112.7019 - 1s/epoch - 5ms/step
# Epoch 153/200
# 250/250 - 1s - loss: 173.1757 - mae: 173.1757 - val_loss: 110.8216 - val_mae: 110.8216 - 1s/epoch - 6ms/step
# Epoch 154/200
# 250/250 - 1s - loss: 175.2956 - mae: 175.2956 - val_loss: 150.1530 - val_mae: 150.1530 - 1s/epoch - 6ms/step
# Epoch 155/200
# 250/250 - 1s - loss: 190.0210 - mae: 190.0210 - val_loss: 131.9996 - val_mae: 131.9996 - 1s/epoch - 6ms/step
# Epoch 156/200
# 250/250 - 1s - loss: 168.1563 - mae: 168.1563 - val_loss: 132.9666 - val_mae: 132.9666 - 1s/epoch - 5ms/step
# Epoch 157/200
# 250/250 - 1s - loss: 173.5966 - mae: 173.5966 - val_loss: 123.1726 - val_mae: 123.1726 - 1s/epoch - 5ms/step
# Epoch 158/200
# 250/250 - 1s - loss: 172.7699 - mae: 172.7699 - val_loss: 120.1149 - val_mae: 120.1149 - 1s/epoch - 6ms/step
# Epoch 159/200
# 250/250 - 1s - loss: 175.6411 - mae: 175.6411 - val_loss: 124.3607 - val_mae: 124.3607 - 1s/epoch - 6ms/step
# Epoch 160/200
# 250/250 - 1s - loss: 170.1762 - mae: 170.1762 - val_loss: 156.1010 - val_mae: 156.1010 - 1s/epoch - 6ms/step
# Epoch 161/200
# 250/250 - 1s - loss: 176.3462 - mae: 176.3462 - val_loss: 109.7591 - val_mae: 109.7591 - 1s/epoch - 6ms/step
# Epoch 162/200
# 250/250 - 1s - loss: 172.4491 - mae: 172.4491 - val_loss: 129.3379 - val_mae: 129.3379 - 1s/epoch - 6ms/step
# Epoch 163/200
# 250/250 - 1s - loss: 173.1348 - mae: 173.1348 - val_loss: 117.8272 - val_mae: 117.8272 - 1s/epoch - 6ms/step
# Epoch 164/200
# 250/250 - 1s - loss: 173.6612 - mae: 173.6612 - val_loss: 114.2316 - val_mae: 114.2316 - 1s/epoch - 5ms/step
# Epoch 165/200
# 250/250 - 1s - loss: 166.9486 - mae: 166.9486 - val_loss: 131.7348 - val_mae: 131.7348 - 1s/epoch - 6ms/step
# Epoch 166/200
# 250/250 - 1s - loss: 171.9283 - mae: 171.9283 - val_loss: 131.8357 - val_mae: 131.8357 - 1s/epoch - 5ms/step
# Epoch 167/200
# 250/250 - 1s - loss: 174.1598 - mae: 174.1598 - val_loss: 124.4097 - val_mae: 124.4097 - 1s/epoch - 6ms/step
# Epoch 168/200
# 250/250 - 1s - loss: 169.3739 - mae: 169.3739 - val_loss: 127.7811 - val_mae: 127.7811 - 1s/epoch - 6ms/step
# Epoch 169/200
# 250/250 - 1s - loss: 166.4447 - mae: 166.4447 - val_loss: 112.3002 - val_mae: 112.3002 - 1s/epoch - 5ms/step
# Epoch 170/200
# 250/250 - 1s - loss: 170.4103 - mae: 170.4103 - val_loss: 122.4193 - val_mae: 122.4193 - 1s/epoch - 5ms/step
# Epoch 171/200
# 250/250 - 1s - loss: 169.1799 - mae: 169.1799 - val_loss: 122.9997 - val_mae: 122.9997 - 1s/epoch - 5ms/step
# Epoch 172/200
# 250/250 - 1s - loss: 168.3905 - mae: 168.3905 - val_loss: 125.2882 - val_mae: 125.2882 - 1s/epoch - 6ms/step
# Epoch 173/200
# 250/250 - 1s - loss: 169.0840 - mae: 169.0840 - val_loss: 112.8721 - val_mae: 112.8721 - 1s/epoch - 6ms/step
# Epoch 174/200
# 250/250 - 1s - loss: 167.6056 - mae: 167.6056 - val_loss: 148.1561 - val_mae: 148.1561 - 1s/epoch - 5ms/step
# Epoch 175/200
# 250/250 - 1s - loss: 174.3070 - mae: 174.3070 - val_loss: 140.4953 - val_mae: 140.4953 - 1s/epoch - 5ms/step
# Epoch 176/200
# 250/250 - 1s - loss: 172.3565 - mae: 172.3565 - val_loss: 135.0769 - val_mae: 135.0769 - 1s/epoch - 5ms/step
# Epoch 177/200
# 250/250 - 1s - loss: 169.8820 - mae: 169.8820 - val_loss: 116.0605 - val_mae: 116.0605 - 1s/epoch - 5ms/step
# Epoch 178/200
# 250/250 - 1s - loss: 166.5318 - mae: 166.5318 - val_loss: 146.0574 - val_mae: 146.0574 - 1s/epoch - 6ms/step
# Epoch 179/200
# 250/250 - 1s - loss: 172.9322 - mae: 172.9322 - val_loss: 108.3145 - val_mae: 108.3145 - 1s/epoch - 5ms/step
# Epoch 180/200
# 250/250 - 1s - loss: 164.3689 - mae: 164.3689 - val_loss: 110.3570 - val_mae: 110.3570 - 1s/epoch - 5ms/step
# Epoch 181/200
# 250/250 - 1s - loss: 174.4513 - mae: 174.4513 - val_loss: 130.0977 - val_mae: 130.0977 - 1s/epoch - 5ms/step
# Epoch 182/200
# 250/250 - 1s - loss: 170.3373 - mae: 170.3373 - val_loss: 113.3332 - val_mae: 113.3332 - 1s/epoch - 6ms/step
# Epoch 183/200
# 250/250 - 1s - loss: 171.6500 - mae: 171.6500 - val_loss: 122.3491 - val_mae: 122.3491 - 1s/epoch - 5ms/step
# Epoch 184/200
# 250/250 - 1s - loss: 173.3368 - mae: 173.3368 - val_loss: 114.0829 - val_mae: 114.0829 - 1s/epoch - 5ms/step
# Epoch 185/200
# 250/250 - 1s - loss: 166.8408 - mae: 166.8408 - val_loss: 109.7180 - val_mae: 109.7180 - 1s/epoch - 6ms/step
# Epoch 186/200
# 250/250 - 1s - loss: 168.5878 - mae: 168.5878 - val_loss: 123.8254 - val_mae: 123.8254 - 1s/epoch - 5ms/step
# Epoch 187/200
# 250/250 - 1s - loss: 167.6622 - mae: 167.6622 - val_loss: 116.3700 - val_mae: 116.3700 - 1s/epoch - 6ms/step
# Epoch 188/200
# 250/250 - 1s - loss: 169.5030 - mae: 169.5030 - val_loss: 129.8230 - val_mae: 129.8230 - 1s/epoch - 6ms/step
# Epoch 189/200
# 250/250 - 1s - loss: 175.2316 - mae: 175.2316 - val_loss: 116.9383 - val_mae: 116.9383 - 1s/epoch - 5ms/step
# Epoch 190/200
# 250/250 - 1s - loss: 174.0954 - mae: 174.0954 - val_loss: 123.6568 - val_mae: 123.6568 - 1s/epoch - 5ms/step
# Epoch 191/200
# 250/250 - 1s - loss: 166.4884 - mae: 166.4884 - val_loss: 115.0944 - val_mae: 115.0944 - 1s/epoch - 5ms/step
# Epoch 192/200
# 250/250 - 1s - loss: 168.4584 - mae: 168.4584 - val_loss: 115.0865 - val_mae: 115.0865 - 1s/epoch - 5ms/step
# Epoch 193/200
# 250/250 - 1s - loss: 171.2552 - mae: 171.2552 - val_loss: 164.4312 - val_mae: 164.4312 - 1s/epoch - 5ms/step
# Epoch 194/200
# 250/250 - 1s - loss: 168.1682 - mae: 168.1682 - val_loss: 119.4062 - val_mae: 119.4062 - 1s/epoch - 5ms/step
# Epoch 195/200
# 250/250 - 1s - loss: 167.5680 - mae: 167.5680 - val_loss: 121.0218 - val_mae: 121.0218 - 1s/epoch - 6ms/step
# Epoch 196/200
# 250/250 - 1s - loss: 169.7538 - mae: 169.7538 - val_loss: 134.0330 - val_mae: 134.0330 - 1s/epoch - 6ms/step
# Epoch 197/200
# 250/250 - 1s - loss: 173.3503 - mae: 173.3503 - val_loss: 113.8750 - val_mae: 113.8750 - 1s/epoch - 6ms/step
# Epoch 198/200
# 250/250 - 1s - loss: 162.4267 - mae: 162.4267 - val_loss: 143.2824 - val_mae: 143.2824 - 1s/epoch - 5ms/step
# Epoch 199/200
# 250/250 - 1s - loss: 173.2947 - mae: 173.2947 - val_loss: 117.6135 - val_mae: 117.6135 - 1s/epoch - 5ms/step
# Epoch 200/200
# 250/250 - 1s - loss: 169.9433 - mae: 169.9433 - val_loss: 115.2647 - val_mae: 115.2647 - 1s/epoch - 6ms/step
# 손실 함수: 115.26473236083984 MAE: 115.26473236083984
# 4/4 [==============================] - 0s 4ms/step
# LSTM 평균절댓값백분율오차(MAPE): [0.01944577 0.00717518 0.01412961 0.01505105]

# %%
# 텐서플로가 제공하는 IMDB 데이터 살펴보기

from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Embedding
from tensorflow.keras import preprocessing

dic_siz=10000 # 사전의 크기(사전에 있는 단어 개수)
sample_siz=512 # 샘플의 크기

# tensorflow가 제공하는 간소한 버전의 IMDB 읽기
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=dic_siz)
print(x_train.shape,x_test.shape)
print(x_train[0])

# 단어를 숫자, 숫자를 단어로 변환하는데 쓰는 표(표는 딕셔너리로 구현)
word2id=imdb.get_word_index()
id2word={word:id for id,word in word2id.items()}

for i in range(1,21):
    print(id2word[i],end='/')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step
# (25000,) (25000,)
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step
# the/and/a/of/to/is/br/in/it/i/this/that/was/as/for/with/movie/but/film/on/

# %%
# 단어 임베딩을 사용해 IMDB 데이터를 부정/긍정 평가로 분류하는 학습 모델


embed_space_dim=16 # 16차원의 임베딩 공간

x_train=preprocessing.sequence.pad_sequences(x_train,maxlen=sample_siz)
x_test=preprocessing.sequence.pad_sequences(x_test,maxlen=sample_siz)

# 신경망 모델 설계와 학습
embed=Sequential()
embed.add(Embedding(input_dim=dic_siz,output_dim=embed_space_dim,input_length=sample_siz))
embed.add(Flatten())
embed.add(Dense(32,activation='relu'))
embed.add(Dense(1,activation='sigmoid'))
embed.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
hist=embed.fit(x_train,y_train,epochs=20,batch_size=64,validation_data=(x_test,y_test),verbose=2)

embed.summary()

# 모델 평가
res=embed.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

# 학습 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()
# Out:
# Epoch 1/20
# 391/391 - 6s - loss: 0.4336 - accuracy: 0.7731 - val_loss: 0.2840 - val_accuracy: 0.8804 - 6s/epoch - 16ms/step
# Epoch 2/20
# 391/391 - 5s - loss: 0.1617 - accuracy: 0.9416 - val_loss: 0.3129 - val_accuracy: 0.8734 - 5s/epoch - 12ms/step
# Epoch 3/20
# 391/391 - 5s - loss: 0.0543 - accuracy: 0.9852 - val_loss: 0.4437 - val_accuracy: 0.8470 - 5s/epoch - 13ms/step
# Epoch 4/20
# 391/391 - 6s - loss: 0.0137 - accuracy: 0.9982 - val_loss: 0.4457 - val_accuracy: 0.8664 - 6s/epoch - 15ms/step
# Epoch 5/20
# 391/391 - 5s - loss: 0.0034 - accuracy: 0.9999 - val_loss: 0.4898 - val_accuracy: 0.8676 - 5s/epoch - 13ms/step
# Epoch 6/20
# 391/391 - 5s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.8698 - 5s/epoch - 13ms/step
# Epoch 7/20
# 391/391 - 5s - loss: 7.3432e-04 - accuracy: 1.0000 - val_loss: 0.5447 - val_accuracy: 0.8704 - 5s/epoch - 13ms/step
# Epoch 8/20
# 391/391 - 5s - loss: 4.8489e-04 - accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.8692 - 5s/epoch - 13ms/step
# Epoch 9/20
# 391/391 - 5s - loss: 3.2857e-04 - accuracy: 1.0000 - val_loss: 0.5883 - val_accuracy: 0.8706 - 5s/epoch - 13ms/step
# Epoch 10/20
# 391/391 - 5s - loss: 2.3222e-04 - accuracy: 1.0000 - val_loss: 0.6078 - val_accuracy: 0.8702 - 5s/epoch - 13ms/step
# Epoch 11/20
# 391/391 - 5s - loss: 1.6878e-04 - accuracy: 1.0000 - val_loss: 0.6247 - val_accuracy: 0.8705 - 5s/epoch - 13ms/step
# Epoch 12/20
# 391/391 - 5s - loss: 1.2585e-04 - accuracy: 1.0000 - val_loss: 0.6415 - val_accuracy: 0.8705 - 5s/epoch - 13ms/step
# Epoch 13/20
# 391/391 - 5s - loss: 9.4164e-05 - accuracy: 1.0000 - val_loss: 0.6587 - val_accuracy: 0.8705 - 5s/epoch - 13ms/step
# Epoch 14/20
# 391/391 - 5s - loss: 7.2152e-05 - accuracy: 1.0000 - val_loss: 0.6749 - val_accuracy: 0.8704 - 5s/epoch - 13ms/step
# Epoch 15/20
# 391/391 - 5s - loss: 5.5274e-05 - accuracy: 1.0000 - val_loss: 0.6894 - val_accuracy: 0.8707 - 5s/epoch - 13ms/step
# Epoch 16/20
# 391/391 - 5s - loss: 4.3058e-05 - accuracy: 1.0000 - val_loss: 0.7047 - val_accuracy: 0.8704 - 5s/epoch - 13ms/step
# Epoch 17/20
# 391/391 - 5s - loss: 3.3373e-05 - accuracy: 1.0000 - val_loss: 0.7191 - val_accuracy: 0.8706 - 5s/epoch - 13ms/step
# Epoch 18/20
# 391/391 - 5s - loss: 2.6097e-05 - accuracy: 1.0000 - val_loss: 0.7340 - val_accuracy: 0.8704 - 5s/epoch - 12ms/step
# Epoch 19/20
# 391/391 - 5s - loss: 2.0491e-05 - accuracy: 1.0000 - val_loss: 0.7483 - val_accuracy: 0.8703 - 5s/epoch - 13ms/step
# Epoch 20/20
# 391/391 - 5s - loss: 1.6115e-05 - accuracy: 1.0000 - val_loss: 0.7626 - val_accuracy: 0.8703 - 5s/epoch - 13ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 512, 16)           160000
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 32)                262176
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 422,209
# Trainable params: 422,209
# Non-trainable params: 0
# _________________________________________________________________
# 정확률은 87.03200221061707

# %%
# 워드 임베딩을 사용하여 IMDB 데이터를 부정/긍정 평가로 분류하는 LSTM 신경망 학습


from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding
from tensorflow.keras import preprocessing
from tensorflow.keras.callbacks import EarlyStopping

dic_siz=10000 # 사전의 크기(사전에 있는 단어 개수)
sample_siz=512 # 샘플의 크기

# tensorflow가 제공하는 간소한 버전의 IMDB 읽기
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=dic_siz)

embed_space_dim=16 # 16차원의 임베딩 공간

x_train=preprocessing.sequence.pad_sequences(x_train,maxlen=sample_siz)
x_test=preprocessing.sequence.pad_sequences(x_test,maxlen=sample_siz)

early=EarlyStopping(monitor='val_accuracy',patience=5,restore_best_weights=True)

# 신경망 모델의 설계와 학습(LSTM 층 포함)
embed=Sequential()
embed.add(Embedding(input_dim=dic_siz,output_dim=embed_space_dim,input_length=sample_siz))
embed.add(LSTM(units=32))
embed.add(Dense(1,activation='sigmoid'))
embed.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
hist=embed.fit(x_train,y_train,epochs=20,batch_size=64,validation_split=0.2,verbose=2,callbacks=[early])

# 모델 평가
res=embed.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

import matplotlib.pyplot as plt

# 학습 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 2s 0us/step
# Epoch 1/20
# 313/313 - 11s - loss: 0.5003 - accuracy: 0.7406 - val_loss: 0.3457 - val_accuracy: 0.8590 - 11s/epoch - 34ms/step
# Epoch 2/20
# 313/313 - 6s - loss: 0.2655 - accuracy: 0.8949 - val_loss: 0.3076 - val_accuracy: 0.8750 - 6s/epoch - 18ms/step
# Epoch 3/20
# 313/313 - 6s - loss: 0.1861 - accuracy: 0.9322 - val_loss: 0.3186 - val_accuracy: 0.8832 - 6s/epoch - 18ms/step
# Epoch 4/20
# 313/313 - 6s - loss: 0.1432 - accuracy: 0.9518 - val_loss: 0.3540 - val_accuracy: 0.8832 - 6s/epoch - 18ms/step
# Epoch 5/20
# 313/313 - 6s - loss: 0.1098 - accuracy: 0.9624 - val_loss: 0.3652 - val_accuracy: 0.8728 - 6s/epoch - 18ms/step
# Epoch 6/20
# 313/313 - 6s - loss: 0.1241 - accuracy: 0.9585 - val_loss: 0.3877 - val_accuracy: 0.8752 - 6s/epoch - 18ms/step
# Epoch 7/20
# 313/313 - 6s - loss: 0.0825 - accuracy: 0.9725 - val_loss: 0.4496 - val_accuracy: 0.8822 - 6s/epoch - 18ms/step
# Epoch 8/20
# 313/313 - 6s - loss: 0.0773 - accuracy: 0.9739 - val_loss: 0.4604 - val_accuracy: 0.8758 - 6s/epoch - 18ms/step
# 정확률은 87.41199970245361
